# %% [markdown]
# ## Match searches with bookings
#
# - For every search in the searches file, find out whether the search ended up in a booking or not (using the info in the bookings file). For instance, search and booking origin and destination should match.
#
# - For the bookings file, origin and destination are the columns dep_port and arr_port, respectively.
#
# - Generate a CSV file with the search data, and an additional field, containing 1 if the search ended up in a booking, and 0 otherwise.

# %% [markdown]
# Suggestion: follow the below plan of action:
#
# * Get familiar with the data
# * Select columns of interest
# * Decide what to do with NaNs
#
# * Make processing plan
# * Develop code that works with a sample
#
# * Adjust the code to work with Big data
# * Test big data approach on a sample
#
# * Run program with big data
#
# You can skip the first step this time, since you already did it for the other exercises

# %% [markdown]
# ## 2) Prepare the data for processing

# %% [markdown]
# ### Booking

# %% [markdown]
# #### We didnt check for duplicates so far... What if the file is has duplicated lines?

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('ggplot')

# %%
bookings_path = 'bookings.csv.bz2'
searches_path = 'searches.csv.bz2'

# %%
bookings = pd.read_csv(bookings_path, sep = '^', nrows = 10000)
searches = pd.read_csv(searches_path, sep = '^', nrows = 10000)

# %%
bookings_types = bookings_sample.dtypes.to_dict()
searches_types = searches_sample.dtypes.to_dict()

# %%
bookings.columns
# Out:
# Index(['act_date           ', 'source', 'pos_ctry', 'pos_iata', 'pos_oid  ',
#        'rloc          ', 'cre_date           ', 'duration', 'distance',
#        'dep_port', 'dep_city', 'dep_ctry', 'arr_port', 'arr_city', 'arr_ctry',
#        'lst_port', 'lst_city', 'lst_ctry', 'brd_port', 'brd_city', 'brd_ctry',
#        'off_port', 'off_city', 'off_ctry', 'mkt_port', 'mkt_city', 'mkt_ctry',
#        'intl', 'route          ', 'carrier', 'bkg_class', 'cab_class',
#        'brd_time           ', 'off_time           ', 'pax', 'year', 'month',
#        'oid      '],
#       dtype='object')

# %%
cols_to_use_bookings = ['cre_date           ','dep_port','arr_port']

# %%
bookings_sample = pd.read_csv(bookings_path, sep = '^', nrows = 100000, dtype=bookings_types,usecols=cols_to_use_bookings)
searches_sample = pd.read_csv(searches_path, sep = '^', nrows = 100000, dtype=searches_types)

# %%
#hacemos la "deduplicacion" de los bookings, con eso podŕiamos hacer una combinación de los dos archivos.
bdeduped_bookings_sample = bookings_sample.drop_duplicates()

# %%
bookings = pd.read_csv(bookings_path, sep = '^', dtype=bookings_types, usecols=cols_to_use_bookings)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/generic.py in __setattr__(self, name, value)
#    3111                 else:
# -> 3112                     object.__setattr__(self, name, value)
#    3113             except (AttributeError, TypeError):
#
# AttributeError: can't set attribute
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# <ipython-input-36-883f20f18b69> in <module>()
#       1 bookings = pd.read_csv(bookings_path, sep = '^', dtype=bookings_types, usecols=cols_to_use_bookings)
#       2 deduped_bookings = bookings_sample.drop_duplicates()
# ----> 3 deduped_bookings.shape = bookings_sample.drop_duplicates()
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/generic.py in __setattr__(self, name, value)
#    3112                     object.__setattr__(self, name, value)
#    3113             except (AttributeError, TypeError):
# -> 3114                 object.__setattr__(self, name, value)
#    3115
#    3116     # ----------------------------------------------------------------------
#
# AttributeError: can't set attribute

# %%
deduped_bookings = bookings.drop_duplicates()
deduped_bookings.shape
# Out:
# (334877, 3)

# %%
bookings.shape
# Out:
# (10000010, 3)

# %% [markdown]
# http://stackoverflow.com/questions/24251219/pandas-read-csv-low-memory-and-dtype-options

# %% [markdown]
# #### We have seen that we have white space in some columns....

# %%
deduped_bookings.columms = deduped_bookings.columns.str.strip()

# %% [markdown]
# #### Could we do this with command line?

# %% [markdown]
# ###  Search

# %% [markdown]
# ### NaN and prepare dates

# %% [markdown]
# ## 3) Make processing plan

# %% [markdown]
# Target: generate a CSV file with the search data, and an additional field, containing 1 if the search ended up in a booking, and 0 otherwise.
#
# 1) remove duplicates
#
# 2) parse dates from string to datetime  (X) NO HACE FALTA
#
# 3) remove whitespaces
#
#     a) from colum names
#
#     b) from content
#
# 4) remove NaN
#
# 5) define the model
#     if there is one booking for a given O&D done at the same day as the search (for a given O&D), ALL searches of the day (for a given 0&D) might have resulted from the same source and will be set with 1.
#     This is regardless of the boarding time of the plane... So if I was looking for plane for the first 4 days of December for a given O&D all those searches would be set to 1 not just the one correspoding to the correct boarding time
#
#         match
#         Search : [search_date, O&D]
#         Booking: [Activity_date, O&D]
#
# 6) execute the model
#
#     a) Group by bookings on [Activity_date, O&D] so that we dont have duplicates (and we can have number of bookings for the day), or we can just drop the duplicates
#
#     b) search left join bookings adding "Booked" column
#
#     c) test if the merge was done right
#
#     d) fill NaN of "booked" column with 0
#
#     e) pull all values of booked column >1 to 1

# %% [markdown]
# more complex... get number of segments from searches
# match search_date, and then split all O&D of all segments, and match the date of first flight of each segment (seg1Date, seg2Date)
# with boarding time and O&D and act_date of booking

# %% [markdown]
# What do we have?

# %%
list(deduped_bookings)
# Out:
# ['cre_date           ', 'dep_port', 'arr_port']

# %%
# Tenemos que cruzar bookings_sample con searches_sample
deduped_bookings['dep_port'] = deduped_bookings['dep_port'].str.strip()
deduped_bookings['cre_date'] = deduped_bookings['cre_date           '].str.strip()
# Out:
# /home/dsc/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /home/dsc/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
#Comprobamos que todo sea igual dentro de la columna:
lens = searches_sample['Origin'].apply(len)
lens.unique()
# Out:
# array([3])

# %%
deduped_bookings['dep_port'] = deduped_bookings['dep_port'].str.strip()
# Out:
# /home/dsc/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
deduped_bookings['arr_port'] = deduped_bookings['arr_port'].str.strip()
# Out:
# /home/dsc/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
joined = searches_sample.merge(deduped_bookings,
                      left_on=['Origin','Destination','Date'],
                      right_on=['dep_port','arr_port','cre_date'],
                      how ='left')

# %%
joined
# Out:
#              Date      Time TxnCode                          OfficeID Country  \
# 0      2013-01-01  20:25:57     MPT  624d8c3ac0b3a7ca03e3c167e0f48327      DE
# 1      2013-01-01  10:15:33     MPT  b0af35b31588dc4ab06d5cf2986e8e02      MD
# 2      2013-01-01  18:04:49     MPT  3561a60621de06ab1badc8ca55699ef3      US
# 3      2013-01-01  17:42:40     FXP  1864e5e8013d9414150e91d26b6a558b      SE
# 4      2013-01-01  17:48:29     MPT  1ec336348f44207d2e0027dc3a68c118      NO
# 5      2013-01-01  22:00:28     MPT  3561a60621de06ab1badc8ca55699ef3      US
# 6      2013-01-01  10:47:14     MPT  d327ca6e35cc6732d4709828327ac7c1      DK
# 7      2013-01-01  23:39:49     MPT  38a3abb0a28e3f00fa79a11f552a5052      FR
# 8      2013-01-01  17:08:46     MPT  c8daef4f8bf73a61aa2c928705f7b82d      ES
# 9      2013-01-01  19:57:57     MPT  28d7a8c95e4db88589d3d35b66920e78      DE
# 10     2013-01-01  18:01:31     MPT  b2771a31dc32d1e4af0ea7d758b8442b      FR
# 11     2013-01-01  09:32:18     FFP  53aea156edeed571bbc473c82b01ac4b      BR
# 12     2013-01-01  05:41:14     CAL  dfa4f720052cefaf2e1fe40befc016e6      HK
# 13     2013-01-01  07:05:45     MPT  d03a30f66f773a65aad66e7bafd1110f      GR
# 14     2013-01-01  03:30:49     MPT  b04e0620a297a1b50819d31535aa5b61      US
# 15     2013-01-01  09:19:41     FCP  7da60d9e60a322d3fff7e00cb62baa53      BR
# 16     2013-01-01  06:20:43     MPT  440642a9bdaeb6287f826cefd73255e8      US
# 17     2013-01-01  18:54:24     MPT  8b4fa4e121637f583bfa86ef0fa26c9e      US
# 18     2013-01-01  10:47:24     MPT  b0af35b31588dc4ab06d5cf2986e8e02      MD
# 19     2013-01-01  19:02:13     MPT  cf4ae41b25a075c3a8fee145e1919199      NL
# 20     2013-01-01  18:38:29     MPT  ef16c4545ce42ab4c753f44780accf94      ES
# 21     2013-01-01  14:07:13     FXP  8e26311e3f5deaceabc65406c823f84d      DE
# 22     2013-01-01  15:14:09     MPT  624d8c3ac0b3a7ca03e3c167e0f48327      DE
# 23     2013-01-01  23:32:58     MPT  624d8c3ac0b3a7ca03e3c167e0f48327      DE
# 24     2013-01-01  10:39:09     MPT  909e0b385888f1305839025d209a5a93      GB
# 25     2013-01-01  13:49:17     MTP  5b0992ae324105dc3d730db5c42569e8      BR
# 26     2013-01-01  21:22:10     MPT  074543ae7a58f4f4c0833d023b2c0db7      CH
# 27     2013-01-01  18:33:28     CCP  3565e31495ecfd46fa018339d20382b1      SA
# 28     2013-01-01  16:59:19     MPT  0c618d30c252b880d8a83ebb76af7643      SE
# 29     2013-01-01  21:25:37     FFP  cb028e2166a95168fee7d483a463ae54      DE
# ...           ...       ...     ...                               ...     ...
# 99970  2013-04-10  01:36:07     MPT  ad5e8547187c6456a514c30f9bfc09ef      US
# 99971  2013-04-10  12:32:19     FXP  8d2a1e767a6c0231e998716660848886      CA
# 99972  2013-04-10  15:26:02     MPT  440642a9bdaeb6287f826cefd73255e8      US
# 99973  2013-04-10  23:44:40     FQD  25fe56b09ab6dc627b3558aecaa627cc      AU
# 99974  2013-04-10  01:19:49     MPT  2a4adcc077363eee1c9a7cd21e89759b      US
# 99975  2013-04-10  12:18:19     MPC  440642a9bdaeb6287f826cefd73255e8      US
# 99976  2013-04-10  14:08:11     MPT  50c54b52322080d2c257390f714f91bd      ES
# 99977  2013-04-10  10:52:15     MPT  cfd7e726d69ea3a852dacad71538a9d0      RU
# 99978  2013-04-10  07:30:11     MPT  0f3f393096afab89ffc5a728018f8f64      GR
# 99979  2013-04-10  13:19:08     MPT  cfd7e726d69ea3a852dacad71538a9d0      RU
# 99980  2013-04-10  11:49:29     MPT  a346d83fed980ff1361f25f3c6566fce      ES
# 99981  2013-04-10  13:58:50     MPT  eb09e499d4fd1f476b88b519f5d9dcc3      NL
# 99982  2013-04-10  18:57:28     MPT  440642a9bdaeb6287f826cefd73255e8      US
# 99983  2013-04-10  19:34:50     MTP  236cbf458f79dbb9d5e9c9430438c3db      US
# 99984  2013-04-10  01:49:11     FFP  53aea156edeed571bbc473c82b01ac4b      BR
# 99985  2013-04-10  09:18:49     FCP  3565e31495ecfd46fa018339d20382b1      SA
# 99986  2013-04-10  16:17:54     MPT  1a5d76accb430232b162739ba7d1379d      DK
# 99987  2013-04-10  09:22:02     MPT  ffe86a95cfb7440489f4515674a957ed      DE
# 99988  2013-04-10  12:29:34     FXP  99a5fa66a00828db9727aea7ebc6ae74      DE
# 99989  2013-04-10  12:00:23     MPT  0bda63f1f542daa78264df28c95fbb6d      NL
# 99990  2013-04-10  08:31:36     MPT  ee937689970080b36e9fef755ce5c8e1      ES
# 99991  2013-04-10  14:09:28     MPT  626ec45e8b1ba8e5ff209c0741e5347a      IE
# 99992  2013-04-10  15:20:57     MPT  440642a9bdaeb6287f826cefd73255e8      US
# 99993  2013-04-10  19:46:38     MTP  236cbf458f79dbb9d5e9c9430438c3db      US
# 99994  2013-04-10  22:25:49     FFP  7da60d9e60a322d3fff7e00cb62baa53      BR
# 99995  2013-04-10  12:51:24     MPT  533d88ecea8b7fb3425bdf1246cb3763      IN
# 99996  2013-04-10  11:18:09     MPT  19901d49edef6724c65e38ee8d5957b7      US
# 99997  2013-04-10  20:40:47     MPT  8b4fa4e121637f583bfa86ef0fa26c9e      US
# 99998  2013-04-10  05:39:16     MPT  8b4fa4e121637f583bfa86ef0fa26c9e      US
# 99999  2013-04-10  12:26:15     MPT  9aa037e8d4135205e54688c113ed7e80      DE
#
#       Origin Destination  RoundTrip  NbSegments Seg1Departure   ...     \
# 0        TXL         AUH          1           2           TXL   ...
# 1        ATH         MIL          0           1           ATH   ...
# 2        ICT         SFO          1           2           ICT   ...
# 3        RNB         ARN          0           1           RNB   ...
# 4        OSL         MAD          1           2           OSL   ...
# 5        IAH         BLR          1           2           IAH   ...
# 6        CPH         PAR          1           2           CPH   ...
# 7        PAR         DUB          1           2           PAR   ...
# 8        DUS         ACE          1           2           DUS   ...
# 9        FRA         BGW          1           2           FRA   ...
# 10       PAR         BUD          1           2           PAR   ...
# 11       RIO         POA          1           2           RIO   ...
# 12       HKG         MXP          1           2           HKG   ...
# 13       BCN         LON          0           1           BCN   ...
# 14       CLE         SNN          1           2           CLE   ...
# 15       BSB         SLZ          0           1           BSB   ...
# 16       PEK         PHL          0           1           PEK   ...
# 17       BOS         GRU          1           2           BOS   ...
# 18       TBS         IKT          0           1           TBS   ...
# 19       LON         HKG          1           2           LON   ...
# 20       MAD         SEA          1           2           MAD   ...
# 21       DUS         STN          1           2           DUS   ...
# 22       PAD         FUE          0           1           PAD   ...
# 23       DUS         IST          1           2           DUS   ...
# 24       BHX         VIE          1           2           BHX   ...
# 25       CGB         SAO          0           1           CGB   ...
# 26       ZRH         BRI          1           2           ZRH   ...
# 27       RUH         JED          0           1           RUH   ...
# 28       UME         CPH          1           2           UME   ...
# 29       FRA         DRS          0           1           FRA   ...
# ...      ...         ...        ...         ...           ...   ...
# 99970    NYC         SJO          1           2           NYC   ...
# 99971    YYZ         YYC          0           1           YYZ   ...
# 99972    SAN         BRU          1           2           SAN   ...
# 99973    SYD         JNB          1           2           SYD   ...
# 99974    BOS         RIO          1           2           BOS   ...
# 99975    FLN         JFK          1           2           FLN   ...
# 99976    BCN         OSL          1           2           BCN   ...
# 99977    MOW         BAK          0           1           MOW   ...
# 99978    CAN         LON          0           1           CAN   ...
# 99979    LED         BER          1           2           LED   ...
# 99980    BUD         MPM          1           2           BUD   ...
# 99981    BCN         DPS          1           2           BCN   ...
# 99982    JFK         BLQ          1           2           JFK   ...
# 99983    JFK         MNL          1           2           JFK   ...
# 99984    THE         REC          1           2           THE   ...
# 99985    EAM         RUH          0           1           EAM   ...
# 99986    MAD         PMI          1           2           MAD   ...
# 99987    HAJ         LON          1           2           HAJ   ...
# 99988    DUS         MUC          1           2           DUS   ...
# 99989    BER         ALG          1           2           BER   ...
# 99990    TCI         ACE          1           2           TCI   ...
# 99991    DUB         LOS          1           2           DUB   ...
# 99992    VIE         BCN          1           2           VIE   ...
# 99993    PHL         LCY          1           2           PHL   ...
# 99994    GRU         JFK          1           2           GRU   ...
# 99995    DEL         TRV          1           2           DEL   ...
# 99996    BUF         AUA          1           2           BUF   ...
# 99997    JFK         KUL          1           2           JFK   ...
# 99998    STL         SEA          0           1           STL   ...
# 99999    MUC         HAM          1           2           MUC   ...
#
#          From IsPublishedForNeg IsFromInternet IsFromVista  \
# 0      1ASIWS                 0              0           0
# 1      1ASIWS                 0              0           0
# 2      1ASIWS                 0              0           0
# 3        1ASI                 0              0           0
# 4      1ASIWS                 0              0           0
# 5      1ASIWS                 0              0           0
# 6        1ASI                 0              0           0
# 7      1ASIWS                 0              0           0
# 8      1ASIWS                 0              0           0
# 9        1ASI                 0              0           0
# 10     1ASIWS                 0              0           0
# 11     1ASIWS                 0              0           0
# 12     1ASIWS                 0              0           0
# 13     1ASIWS                 0              0           0
# 14       1ASI                 0              0           0
# 15     1ASIWS                 0              0           0
# 16     1ASIWS                 0              0           0
# 17     1ASIWS                 0              0           0
# 18     1ASIWS                 0              0           0
# 19       1ASI                 0              0           0
# 20     1ASIWS                 0              0           0
# 21       1ASI                 0              0           0
# 22     1ASIWS                 0              0           0
# 23     1ASIWS                 0              0           0
# 24       1ASI                 0              0           0
# 25     1ASIWS                 0              0           0
# 26       1ASI                 0              0           0
# 27     1ASIWS                 0              0           0
# 28       1ASI                 0              0           0
# 29     1ASIWS                 0              0           0
# ...       ...               ...            ...         ...
# 99970    1ASI                 0              0           0
# 99971    1ASI                 0              0           0
# 99972  1ASIWS                 0              0           0
# 99973    1ASI                 0              0           0
# 99974  1ASIWS                 0              0           0
# 99975  1ASIWS                 0              0           0
# 99976    1ASI                 0              0           0
# 99977  1ASIWS                 0              0           0
# 99978  1ASIWS                 0              0           0
# 99979  1ASIWS                 0              0           0
# 99980    1ASI                 0              0           0
# 99981  1ASIWS                 0              0           0
# 99982  1ASIWS                 0              0           0
# 99983  1ASIWS                 0              0           0
# 99984  1ASIWS                 0              0           0
# 99985  1ASIWS                 0              0           0
# 99986  1ASIWS                 0              0           0
# 99987  1ASIWS                 0              0           0
# 99988    1ASI                 0              0           0
# 99989    1ASI                 0              0           0
# 99990    1ASI                 0              0           0
# 99991    1ASI                 0              0           0
# 99992  1ASIWS                 0              0           0
# 99993  1ASIWS                 0              0           0
# 99994  1ASIWS                 0              0           0
# 99995  1ASIWS                 0              0           0
# 99996  1ASIWS                 0              0           0
# 99997  1ASIWS                 0              0           0
# 99998  1ASIWS                 0              0           0
# 99999    1ASI                 0              0           0
#
#                              TerminalID InternetOffice cre_date             \
# 0      d41d8cd98f00b204e9800998ecf8427e            FRA                 NaN
# 1      d41d8cd98f00b204e9800998ecf8427e            KIV                 NaN
# 2      d41d8cd98f00b204e9800998ecf8427e            NYC                 NaN
# 3      d41d8cd98f00b204e9800998ecf8427e            STO                 NaN
# 4      d41d8cd98f00b204e9800998ecf8427e            OSL                 NaN
# 5      d41d8cd98f00b204e9800998ecf8427e            NYC                 NaN
# 6      d41d8cd98f00b204e9800998ecf8427e            CPH                 NaN
# 7      d41d8cd98f00b204e9800998ecf8427e            PAR                 NaN
# 8      d41d8cd98f00b204e9800998ecf8427e            MAD                 NaN
# 9      d41d8cd98f00b204e9800998ecf8427e            BNJ                 NaN
# 10     d41d8cd98f00b204e9800998ecf8427e            PAR                 NaN
# 11     d41d8cd98f00b204e9800998ecf8427e            SAO                 NaN
# 12     d41d8cd98f00b204e9800998ecf8427e            HKG                 NaN
# 13     d41d8cd98f00b204e9800998ecf8427e            ATH                 NaN
# 14     d41d8cd98f00b204e9800998ecf8427e            DTW                 NaN
# 15     d41d8cd98f00b204e9800998ecf8427e            SAO                 NaN
# 16     d41d8cd98f00b204e9800998ecf8427e            HPN                 NaN
# 17     d41d8cd98f00b204e9800998ecf8427e            LAS                 NaN
# 18     d41d8cd98f00b204e9800998ecf8427e            KIV                 NaN
# 19     d41d8cd98f00b204e9800998ecf8427e            AMS                 NaN
# 20     d41d8cd98f00b204e9800998ecf8427e            BCN                 NaN
# 21     d41d8cd98f00b204e9800998ecf8427e            BER                 NaN
# 22     d41d8cd98f00b204e9800998ecf8427e            FRA                 NaN
# 23     d41d8cd98f00b204e9800998ecf8427e            FRA                 NaN
# 24     d41d8cd98f00b204e9800998ecf8427e            LON                 NaN
# 25     d41d8cd98f00b204e9800998ecf8427e            RIO                 NaN
# 26     d41d8cd98f00b204e9800998ecf8427e            GVA                 NaN
# 27     d41d8cd98f00b204e9800998ecf8427e            JED                 NaN
# 28     d41d8cd98f00b204e9800998ecf8427e            STO                 NaN
# 29     d41d8cd98f00b204e9800998ecf8427e            FRA                 NaN
# ...                                 ...            ...                 ...
# 99970  d41d8cd98f00b204e9800998ecf8427e            DCA                 NaN
# 99971  d41d8cd98f00b204e9800998ecf8427e            YYZ                 NaN
# 99972  d41d8cd98f00b204e9800998ecf8427e            HPN                 NaN
# 99973  67c1866821dc07c6916e31d39473a3b0            SYD                 NaN
# 99974  d41d8cd98f00b204e9800998ecf8427e            LAX                 NaN
# 99975  d41d8cd98f00b204e9800998ecf8427e            HPN                 NaN
# 99976  d41d8cd98f00b204e9800998ecf8427e            MAD                 NaN
# 99977  d41d8cd98f00b204e9800998ecf8427e            MOW                 NaN
# 99978  d41d8cd98f00b204e9800998ecf8427e            ATH                 NaN
# 99979  d41d8cd98f00b204e9800998ecf8427e            MOW                 NaN
# 99980  d41d8cd98f00b204e9800998ecf8427e            MAD                 NaN
# 99981  d41d8cd98f00b204e9800998ecf8427e            AMS                 NaN
# 99982  d41d8cd98f00b204e9800998ecf8427e            HPN                 NaN
# 99983  d41d8cd98f00b204e9800998ecf8427e            HPN                 NaN
# 99984  d41d8cd98f00b204e9800998ecf8427e            SAO                 NaN
# 99985  d41d8cd98f00b204e9800998ecf8427e            JED                 NaN
# 99986  d41d8cd98f00b204e9800998ecf8427e            CPH                 NaN
# 99987  d41d8cd98f00b204e9800998ecf8427e            FRA                 NaN
# 99988  9a3f0937569d83b3e256abee8f5d17ef            BER                 NaN
# 99989  d41d8cd98f00b204e9800998ecf8427e            AMS                 NaN
# 99990  d41d8cd98f00b204e9800998ecf8427e            MAD                 NaN
# 99991  d41d8cd98f00b204e9800998ecf8427e            DUB                 NaN
# 99992  d41d8cd98f00b204e9800998ecf8427e            HPN                 NaN
# 99993  d41d8cd98f00b204e9800998ecf8427e            HPN                 NaN
# 99994  d41d8cd98f00b204e9800998ecf8427e            SAO                 NaN
# 99995  d41d8cd98f00b204e9800998ecf8427e            DEL                 NaN
# 99996  d41d8cd98f00b204e9800998ecf8427e            NYC                 NaN
# 99997  d41d8cd98f00b204e9800998ecf8427e            LAS                 NaN
# 99998  d41d8cd98f00b204e9800998ecf8427e            LAS                 NaN
# 99999  d41d8cd98f00b204e9800998ecf8427e            BER                 NaN
#
#       dep_port arr_port cre_date
# 0          NaN      NaN      NaN
# 1          NaN      NaN      NaN
# 2          NaN      NaN      NaN
# 3          NaN      NaN      NaN
# 4          NaN      NaN      NaN
# 5          NaN      NaN      NaN
# 6          NaN      NaN      NaN
# 7          NaN      NaN      NaN
# 8          NaN      NaN      NaN
# 9          NaN      NaN      NaN
# 10         NaN      NaN      NaN
# 11         NaN      NaN      NaN
# 12         NaN      NaN      NaN
# 13         NaN      NaN      NaN
# 14         NaN      NaN      NaN
# 15         NaN      NaN      NaN
# 16         NaN      NaN      NaN
# 17         NaN      NaN      NaN
# 18         NaN      NaN      NaN
# 19         NaN      NaN      NaN
# 20         NaN      NaN      NaN
# 21         NaN      NaN      NaN
# 22         NaN      NaN      NaN
# 23         NaN      NaN      NaN
# 24         NaN      NaN      NaN
# 25         NaN      NaN      NaN
# 26         NaN      NaN      NaN
# 27         NaN      NaN      NaN
# 28         NaN      NaN      NaN
# 29         NaN      NaN      NaN
# ...        ...      ...      ...
# 99970      NaN      NaN      NaN
# 99971      NaN      NaN      NaN
# 99972      NaN      NaN      NaN
# 99973      NaN      NaN      NaN
# 99974      NaN      NaN      NaN
# 99975      NaN      NaN      NaN
# 99976      NaN      NaN      NaN
# 99977      NaN      NaN      NaN
# 99978      NaN      NaN      NaN
# 99979      NaN      NaN      NaN
# 99980      NaN      NaN      NaN
# 99981      NaN      NaN      NaN
# 99982      NaN      NaN      NaN
# 99983      NaN      NaN      NaN
# 99984      NaN      NaN      NaN
# 99985      NaN      NaN      NaN
# 99986      NaN      NaN      NaN
# 99987      NaN      NaN      NaN
# 99988      NaN      NaN      NaN
# 99989      NaN      NaN      NaN
# 99990      NaN      NaN      NaN
# 99991      NaN      NaN      NaN
# 99992      NaN      NaN      NaN
# 99993      NaN      NaN      NaN
# 99994      NaN      NaN      NaN
# 99995      NaN      NaN      NaN
# 99996      NaN      NaN      NaN
# 99997      NaN      NaN      NaN
# 99998      NaN      NaN      NaN
# 99999      NaN      NaN      NaN
#
# [100000 rows x 49 columns]

# %%
deduped_bookings['OnlyDate'] = deduped_bookings['cre_date'].str[:10]
# Out:
# /home/dsc/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
searches_matched = joined.drop(['OnlyDate','dep_port','arr_port'],axis=1)
searches_matched['booked'][searches_matched['booked'].isnull()]=0
#otra opción es searchesmatched['booked'] = searches_matched['booked'].fillna(0)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-64-50c0768c5ae6> in <module>()
# ----> 1 searches_matched = joined.drop(['OnlyDate','dep_port','arr_port'],axis=1)
#       2 searches_matched['booked'][searches_matched['booked'].isnull()]=0
#       3 #otra opción es searchesmatched['booked'] = searches_matched['booked'].fillna(0)
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/generic.py in drop(self, labels, axis, level, inplace, errors)
#    2159                 new_axis = axis.drop(labels, level=level, errors=errors)
#    2160             else:
# -> 2161                 new_axis = axis.drop(labels, errors=errors)
#    2162             dropped = self.reindex(**{axis_name: new_axis})
#    2163             try:
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/indexes/base.py in drop(self, labels, errors)
#    3622             if errors != 'ignore':
#    3623                 raise ValueError('labels %s not contained in axis' %
# -> 3624                                  labels[mask])
#    3625             indexer = indexer[~mask]
#    3626         return self.delete(indexer)
#
# ValueError: labels ['OnlyDate'] not contained in axis

# %% [markdown]
# #### If we dont want to drop the duplicates

# %% [markdown]
# ### Now we have to put 1 to all the booking with Num of Bookings>1 in the clean file

# %% [markdown]
# ### Can we do it with concat?
# no, since it just joins on the index

# %% [markdown]
# ### Check if all airports are letters
