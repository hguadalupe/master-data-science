# %%
import pandas as pd
import numpy as np
import csv
from sqlalchemy import create_engine

# %%
#PRUEBA DE ABRIR ARCHIVO CON SOLO DOS COLUMNAS. TIPO DE REGISTRO Y EL RESTO. 
file= './28_900_U_2017-09-23.CAT'
c_file= './28_900_U_2017-09-23.CAT.gz'

file_sample = pd.read_csv(c_file,nrows=100,index_col=False,error_bad_lines=False)

# %%
file= './28_900_U_2017-09-23.CAT'
c_file= './28_900_U_2017-09-23.CAT.gz'
indcols=[0,2,23,25,28,30,44,50,52,77,80,83,123,153,158,163,188,192,193,197,198,203,
       207,215,240,245,247,250,252,255,260,265,295,305,312,319,326,333,342,352,581,601,
      666,676,1000]
namcols=['tipo_reg','n1','cod_meh','cod_mundgc','n2','ref_cat','n3','provinc','cod_mundgc','cod_munine',
        'nom_mun','nom_ent','cod_via','tipo_via','nom_via','poli1','poli2','poli3','poli4','km','bloque',
        'n4','direccion','cp','cod_munag','cod_zon','cod_pol','cod_parcela','cod_parag','nom_parag',
        'superf_finca','superf_const_tot','superf_const_sobreras','superf_const_bajoras','superf_cub',
        'coord_x','coord_y','n5','ref_catbice','denom_bice','huso_srs','n6','d']

file_sample = pd.read_csv(c_file,nrows=100,index_col=False,error_bad_lines=False)

# !ls -lah ./28_900_U_2017-09-23.CAT

print(file_sample.shape)
print(file_sample.columns)
print(file_sample.head)
# Out:
# -rw-rw-r-- 1 dsc dsc 5.8G Dec 23 11:33 ./28_900_U_2017-09-23.CAT
# (100, 1)
# Index(['01G28       MADRID                     20170923123052CCATDESCRIPCION DE BIENES (20-11-2009)                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            '], dtype='object')
# <bound method NDFrame.head of    01G28       MADRID                     20170923123052CCATDESCRIPCION DE BIENES (20-11-2009)
# 0   11                     28900  13000H2DS1810D  ...
# 1   15                     28900UR13000H2DS1810D00...
# 2   11                     28900  4626402VK4482E  ...
# 3   13                     28900UR4626402VK4482E00...
# 4   13                     28900UR4626402VK4482E00...
# 5   13                     28900UR4626402VK4482E00...
# 6   13                     28900UR4626402VK4482E00...
# 7   13                     28900UR4626402VK4482E00...
# 8   14                     28900  4626402VK4482E02...
# 9   14                     28900  4626402VK4482E01...
# 10  14                     28900  4626402VK4482E02...
# 11  14                     28900  4626402VK4482E02...
# 12  14                     28900  4626402VK4482E02...
# 13  14                     28900  4626402VK4482E02...
# 14  14                     28900  4626402VK4482E02...
# 15  14                     28900  4626402VK4482E02...
# 16  14                     28900  4626402VK4482E02...
# 17  14                     28900  4626402VK4482E02...
# 18  14                     28900  4626402VK4482E02...
# 19  14                     28900  4626402VK4482E02...
# 20  14                     28900  4626402VK4482E02...
# 21  14                     28900  4626402VK4482E02...
# 22  14                     28900  4626402VK4482E02...
# 23  14                     28900  4626402VK4482E02...
# 24  14                     28900  4626402VK4482E02...
# 25  14                     28900  4626402VK4482E02...
# 26  14                     28900  4626402VK4482E02...
# 27  14                     28900  4626402VK4482E02...
# 28  14                     28900  4626402VK4482E02...
# 29  14                     28900  4626402VK4482E02...
# ..                                                ...
# 70  14                     28900  4626402VK4482E02...
# 71  14                     28900  4626402VK4482E02...
# 72  14                     28900  4626402VK4482E02...
# 73  14                     28900  4626402VK4482E02...
# 74  14                     28900  4626402VK4482E02...
# 75  14                     28900  4626402VK4482E02...
# 76  14                     28900  4626402VK4482E01...
# 77  14                     28900  4626402VK4482E01...
# 78  14                     28900  4626402VK4482E01...
# 79  14                     28900  4626402VK4482E01...
# 80  14                     28900  4626402VK4482E01...
# 81  14                     28900  4626402VK4482E01...
# 82  14                     28900  4626402VK4482E01...
# 83  14                     28900  4626402VK4482E01...
# 84  14                     28900  4626402VK4482E01...
# 85  14                     28900  4626402VK4482E01...
# 86  14                     28900  4626402VK4482E01...
# 87  14                     28900  4626402VK4482E01...
# 88  14                     28900  4626402VK4482E01...
# 89  14                     28900  4626402VK4482E01...
# 90  14                     28900  4626402VK4482E01...
# 91  14                     28900  4626402VK4482E01...
# 92  14                     28900  4626402VK4482E01...
# 93  14                     28900  4626402VK4482E00...
# 94  14                     28900  4626402VK4482E00...
# 95  14                     28900  4626402VK4482E00...
# 96  14                     28900  4626402VK4482E00...
# 97  14                     28900  4626402VK4482E00...
# 98  14                     28900  4626402VK4482E01...
# 99  14                     28900  4626402VK4482E01...
#
# [100 rows x 1 columns]>

# %%
serie1=file_sample.iloc[:,0]

slice1= serie1.str.slice( start=30, stop=44)
print(slice1)especialis
# Out:
# 0     13000H2DS1810D
# 1     13000H2DS1810D
# 2     4626402VK4482E
# 3     4626402VK4482E
# 4     4626402VK4482E
# 5     4626402VK4482E
# 6     4626402VK4482E
# 7     4626402VK4482E
# 8     4626402VK4482E
# 9     4626402VK4482E
# 10    4626402VK4482E
# 11    4626402VK4482E
# 12    4626402VK4482E
# 13    4626402VK4482E
# 14    4626402VK4482E
# 15    4626402VK4482E
# 16    4626402VK4482E
# 17    4626402VK4482E
# 18    4626402VK4482E
# 19    4626402VK4482E
# 20    4626402VK4482E
# 21    4626402VK4482E
# 22    4626402VK4482E
# 23    4626402VK4482E
# 24    4626402VK4482E
# 25    4626402VK4482E
# 26    4626402VK4482E
# 27    4626402VK4482E
# 28    4626402VK4482E
# 29    4626402VK4482E
#            ...
# 70    4626402VK4482E
# 71    4626402VK4482E
# 72    4626402VK4482E
# 73    4626402VK4482E
# 74    4626402VK4482E
# 75    4626402VK4482E
# 76    4626402VK4482E
# 77    4626402VK4482E
# 78    4626402VK4482E
# 79    4626402VK4482E
# 80    4626402VK4482E
# 81    4626402VK4482E
# 82    4626402VK4482E
# 83    4626402VK4482E
# 84    4626402VK4482E
# 85    4626402VK4482E
# 86    4626402VK4482E
# 87    4626402VK4482E
# 88    4626402VK4482E
# 89    4626402VK4482E
# 90    4626402VK4482E
# 91    4626402VK4482E
# 92    4626402VK4482E
# 93    4626402VK4482E
# 94    4626402VK4482E
# 95    4626402VK4482E
# 96    4626402VK4482E
# 97    4626402VK4482E
# 98    4626402VK4482E
# 99    4626402VK4482E
# Name: 01G28       MADRID                     20170923123052CCATDESCRIPCION DE BIENES (20-11-2009)                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            , Length: 100, dtype: object

# %%
print(len(namcols))
print(len(indcols))
# Out:
# 43
# 45
