# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib
# C:\Users\J.H\Anaconda3\lib\site-packages\IPython\core\magics\pylab.py:160: UserWarning: pylab import has clobbered these variables: ['clf']
# `%matplotlib` prevents importing * from pylab and numpy
#   "\n`%matplotlib` prevents importing * from pylab and numpy"

# %%
df = pd.read_csv("./data/incomplete_smiley.csv")

# %%
df.head()
# Out:
#    Unnamed: 0   x   y   color
# 0        1160  11  60  yellow
# 1        9945  99  45  yellow
# 2        7608  76   8  yellow
# 3        1828  18  28  yellow
# 4        7068  70  68  yellow

# %%
plt.scatter(df["x"],df["y"],c=df["color"])

# %%
X=df[["x","y"]].values
y=df["color"].values
y=list(map(lambda e : 0 if e== "yellow" else 1, y))

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import GradientBoostingClassifier

clf = KNeighborsClassifier(n_neighbors=5)
clf.fit(X,y)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-14-a47b60952e2b> in <module>()
#       1 from sklearn.neighbors import KNeighborsClassifier
#       2 from sklearn.ensemble import GradientBoostingClassifier
# ----> 3 from sklearn import predict
#       4 clf = KNeighborsClassifier(n_neighbors=5)
#       5 clf.fit(X,y)
#
# ImportError: cannot import name 'predict'

# %%
h = .1
x_min, x_max = X[:, 0].min() - 0.1, X[:, 0].max() + .1
y_min, y_max = X[:, 1].min() - .1, X[:, 1].max() + .1
xx, yy = np.meshgrid(np.arange(x_min, x_max, h),
                         np.arange(y_min, y_max, h))
Z = clf.predict(np.c_[xx.ravel(), yy.ravel()])
Z = Z.reshape(xx.shape)

plt.figure(figsize=(10,10))
plt.scatter(xx, yy,c=Z)
plt.scatter(X[:,0],X[:,1],c=y,cmap="rainbow")
plt.show()
