# %%
from windrose import WindroseAxes
from matplotlib import pyplot as plt
import matplotlib.cm as cm
from numpy.random import random
from numpy import arange
import pandas as pd

# %%
file = './DBs/Software_BIM.csv'
softw = pd.read_csv(file)

# %%
softw.loc[:,['MODELADO COMPLEJO',
 'SOFTWARE',
 '4D/5D',
 'BIM EN OBRA',
 'ARQUITECTURA',
 'EDITABILIDAD BIM',
 'ESTRUCTURAS',
 'GEOTÉCNIA',
 'INFRAESTRUCTURAS',
 'INTERCAMBIO BIM',
 'INTEROPERABILIDAD',
 'MEP ELÉCTRICA',
 'MEP. MECÁNICA',
 'SENCILLEZ',
 'SOSTENIBILIDAD',
 'Count of SOFTWARE',
 'COMUNIDAD',
 'EDITABILIDAD SOFTWARE',
 'FLEXIBILIDAD SOFTWARE']]
# Out:
#     MODELADO COMPLEJO                                        SOFTWARE 4D/5D  \
# 0                   5  4MSA FineHVAC + FineLIFT + FineELEC + FineSANI    NO
# 1                   5                            4MSA Strad and Steel    NO
# 2                   2                                AutoCAD civil 3D    NO
# 3                   4                             Autodesk Navisworks    SÍ
# 4                   5              Autodesk Robot Structural Analysis    NO
# 5                   1                             Bentley ConstrucSim    SÍ
# 6                   5            Bentley Hevacomp Mechanical designer    NO
# 7                   5                 Bentley RAM, STAAD and ProSteel    NO
# 8                   5                      Bentley Structural Modeler    NO
# 9                   1                        BIM 360 Field (Autodesk)    NO
# 10                  5                      CADMEP (CADduct / CADmech)    SÍ
# 11                  5                                         CypeCAD    NO
# 12                  5                    Glue (by Horizontal Systems)    SÍ
# 13                  5                          Graytec Advance design    NO
# 14                  2                                      Infraworks    NO
# 15                  5                                        InNOvaya    SÍ
# 16                  5                                        Keynetix    NO
# 17                  5                                 Nemetschek Scia    NO
# 18                  5                                        Primtech    SÍ
# 19                  4                                 RhiNOBIM (BETA)    NO
# 20                  5                           Solibri Model Checker    SÍ
# 21                  5                 StructureSoft Metal Wood Framer    NO
# 22                  5                            Synchro Professional    SÍ
# 23                  5                                  Tekla BIMSight    SÍ
# 24                  5                                Tekla Structures    NO
# 25                  5                                  Vela Field BIM    SÍ
# 26                  5                               Vico Office Suite    SÍ
# 27                  5                        AECOsim Energy Simulator    NO
# 28                  5                       Autodesk Ecotect Analysis    NO
# 29                  5                  Autodesk Green Building Studio    NO
# 30                  4                                  Autodesk Revit    SÍ
# 31                  3                            Bentley Architecture    NO
# 32                  5                              Bentley Facilities    NO
# 33                  5                                Bentley Hevacomp    NO
# 34                  5                                   DesignBuilder    NO
# 35                  5                                        EcoDomus    SÍ
# 36                  5                          FM:Systems FM:Interact    NO
# 37                  3                             Graphisoft ArchiCAD    NO
# 38                  5                          Graphisoft Ecodesigner    NO
# 39                  5        IES Solutions Virtual Environment VE-Pro    NO
# 40                  2                              Nemetschek Allplan    SÍ
# 41                  2                          Nemetschek Vectorworks    NO
# 42                  5                                    Onuma System    SÍ
# 43                  5                 Vintocon ArchiFM (For ArchiCAD)    NO
#
#    BIM EN OBRA ARQUITECTURA  EDITABILIDAD BIM ESTRUCTURAS GEOTÉCNIA  \
# 0           NO           NO                 5          NO        NO
# 1           NO           NO                 5          SÍ        NO
# 2           NO           NO                 2          SÍ        SÍ
# 3           SÍ           NO                 3          NO        NO
# 4           NO           NO                 5          SÍ        NO
# 5           NO           NO                 1          NO        NO
# 6           NO           NO                 5          NO        NO
# 7           NO           NO                 5          SÍ        NO
# 8           NO           NO                 5          SÍ        NO
# 9           SÍ           NO                 1          NO        NO
# 10          NO           NO                 5          NO        NO
# 11          NO           NO                 5          SÍ        NO
# 12          NO           NO                 5          NO        NO
# 13          NO           NO                 5          SÍ        NO
# 14          NO           NO                 2          SÍ        NO
# 15          NO           NO                 5          NO        NO
# 16          NO           NO                 5          NO        SÍ
# 17          NO           NO                 5          SÍ        NO
# 18          NO           NO                 5          NO        NO
# 19          NO           SÍ                 4          SÍ        NO
# 20          NO           NO                 5          NO        NO
# 21          NO           NO                 5          SÍ        NO
# 22          NO           NO                 5          NO        NO
# 23          NO           NO                 5          NO        NO
# 24          NO           NO                 5          SÍ        NO
# 25          NO           NO                 5          NO        NO
# 26          NO           NO                 5          NO        NO
# 27          NO           NO                 5          NO        NO
# 28          NO           NO                 5          NO        NO
# 29          NO           NO                 5          NO        NO
# 30          NO           SÍ                 4          SÍ        NO
# 31          NO           SÍ                 3          SÍ        NO
# 32          NO           NO                 5          NO        NO
# 33          NO           NO                 5          NO        NO
# 34          NO           SÍ                 5          NO        NO
# 35          NO           NO                 5          NO        NO
# 36          NO           NO                 5          NO        NO
# 37          NO           SÍ                 3          NO        NO
# 38          NO           NO                 5          NO        NO
# 39          NO           NO                 5          NO        NO
# 40          NO           SÍ                 4          SÍ        NO
# 41          NO           SÍ                 2          NO        NO
# 42          SÍ           NO                 5          NO        NO
# 43          NO           NO                 5          NO        NO
#
#    INFRAESTRUCTURAS INTERCAMBIO BIM  INTEROPERABILIDAD MEP ELÉCTRICA  \
# 0                NO              NO                  5            NO
# 1                NO              NO                  5            NO
# 2                SÍ              NO                  2            NO
# 3                NO              SÍ                  5            NO
# 4                NO              NO                  5            NO
# 5                NO              NO                  5            NO
# 6                NO              NO                  5            NO
# 7                NO              NO                  5            NO
# 8                NO              NO                  5            NO
# 9                NO              NO                  4            NO
# 10               NO              NO                  5            NO
# 11               NO              NO                  5            NO
# 12               NO              NO                  5            NO
# 13               NO              NO                  5            NO
# 14               SÍ              NO                  3            NO
# 15               NO              NO                  5            NO
# 16               NO              NO                  5            NO
# 17               NO              NO                  5            NO
# 18               NO              NO                  5            NO
# 19               NO              NO                  4            NO
# 20               NO              NO                  5            NO
# 21               NO              NO                  5            NO
# 22               NO              NO                  5            NO
# 23               NO              NO                  5            NO
# 24               NO              NO                  5            NO
# 25               NO              NO                  5            NO
# 26               NO              NO                  5            NO
# 27               NO              NO                  5            NO
# 28               NO              NO                  5            NO
# 29               NO              NO                  3            NO
# 30               NO              SÍ                  4            SÍ
# 31               SÍ              SÍ                  2            SÍ
# 32               NO              NO                  5            SÍ
# 33               NO              NO                  5            SÍ
# 34               NO              NO                  5            NO
# 35               NO              NO                  5            NO
# 36               NO              NO                  5            NO
# 37               NO              NO                  2            NO
# 38               NO              NO                  5            NO
# 39               NO              NO                  5            NO
# 40               NO              NO                  4            NO
# 41               NO              SÍ                  4            NO
# 42               NO              SÍ                  5            NO
# 43               NO              NO                  5            NO
#
#    MEP. MECÁNICA  SENCILLEZ SOSTENIBILIDAD  Count of SOFTWARE  COMUNIDAD  \
# 0             SÍ          5             NO                NaN          5
# 1             NO          5             NO                NaN          5
# 2             NO          4             NO                NaN          4
# 3             NO          4             NO                NaN          1
# 4             NO          3             NO                NaN          2
# 5             NO          3             NO                NaN          1
# 6             SÍ          5             NO                NaN          5
# 7             NO          5             NO                NaN          4
# 8             NO          5             NO                NaN          4
# 9             NO          3             NO                NaN          1
# 10            SÍ          5             NO                NaN          5
# 11            NO          5             NO                NaN          2
# 12            NO          5             NO                NaN          5
# 13            NO          5             NO                NaN          5
# 14            NO          4             NO                NaN          1
# 15            NO          5             NO                NaN          5
# 16            NO          1             NO                NaN          5
# 17            NO          5             NO                NaN          5
# 18            NO          5             NO                NaN          5
# 19            SÍ          4             NO                NaN          4
# 20            NO          4             NO                NaN          5
# 21            NO          5             NO                NaN          5
# 22            NO          5             NO                NaN          5
# 23            NO          5             NO                NaN          5
# 24            NO          4             NO                NaN          3
# 25            NO          5             NO                NaN          5
# 26            NO          3             NO                NaN          5
# 27            NO          5             SÍ                NaN          1
# 28            NO          3             SÍ                NaN          1
# 29            NO          2             SÍ                NaN          1
# 30            SÍ          4             SÍ                NaN          3
# 31            SÍ          2             SÍ                NaN          4
# 32            SÍ          5             SÍ                NaN          5
# 33            SÍ          5             SÍ                NaN          1
# 34            SÍ          5             SÍ                NaN          1
# 35            NO          5             SÍ                NaN          5
# 36            NO          5             SÍ                NaN          5
# 37            NO          3             SÍ                NaN          3
# 38            NO          5             SÍ                NaN          1
# 39            NO          5             SÍ                NaN          1
# 40            NO          1             SÍ                NaN          3
# 41            NO          2             SÍ                NaN          2
# 42            NO          5             SÍ                NaN          5
# 43            NO          5             SÍ                NaN          5
#
#     EDITABILIDAD SOFTWARE  FLEXIBILIDAD SOFTWARE
# 0                       5                      5
# 1                       5                      5
# 2                       2                      1
# 3                       3                      3
# 4                       5                      5
# 5                       4                      3
# 6                       5                      5
# 7                       5                      5
# 8                       5                      5
# 9                       4                      1
# 10                      5                      5
# 11                      5                      5
# 12                      5                      5
# 13                      5                      5
# 14                      4                      1
# 15                      5                      5
# 16                      5                      5
# 17                      5                      5
# 18                      3                      1
# 19                      3                      3
# 20                      5                      5
# 21                      5                      5
# 22                      5                      5
# 23                      5                      5
# 24                      5                      5
# 25                      5                      5
# 26                      5                      5
# 27                      5                      5
# 28                      5                      5
# 29                      5                      5
# 30                      3                      4
# 31                      1                      1
# 32                      5                      5
# 33                      5                      5
# 34                      5                      5
# 35                      5                      5
# 36                      5                      5
# 37                      2                      3
# 38                      5                      5
# 39                      5                      5
# 40                      2                      2
# 41                      2                      1
# 42                      5                      5
# 43                      5                      5

# %%
#Renombramos columnas:

colnm = list(softw)
def space_filler(namelist):
    nwnamelist=[]
    for i in namelist:
        nwname=''
        for j in i:
            if j==' ':
                nwname = nwname + '_'
            elif j=='.':
                nwname = nwname + ''
            elif j=='Á':
                nwname = nwname + 'A'
            elif j=='É':
                nwname = nwname + 'E'
            elif j=='Í':
                nwname = nwname + 'I'
            elif j=='Ó':
                nwname = nwname + 'O'
            elif j=='Ú':
                nwname = nwname + 'U'
            else:
                nwname = nwname + j
        nwnamelist.append(nwname)
    return nwnamelist

ncolnm = space_filler(colnm)

softw = softw.rename(columns= dict(zip(colnm,ncolnm)))
list(softw)
# Out:
# ['SOSTENIBILIDAD',
#  'SOFTWARE',
#  'SENCILLEZ',
#  'MODELADO_COMPLEJO',
#  'MEP_MECANICA',
#  'MEP_ELECTRICA',
#  'INTEROPERABILIDAD',
#  'INTERCAMBIO_BIM',
#  'INFRAESTRUCTURAS',
#  'GEOTECNIA',
#  'FLEXIBILIDAD_SOFTWARE',
#  'ESTRUCTURAS',
#  'EDITABILIDAD_SOFTWARE',
#  'EDITABILIDAD_BIM',
#  'COMUNIDAD',
#  'BIM_EN_OBRA',
#  'ARQUITECTURA',
#  '4D/5D']

# %%
ax = WindroseAxes.from_ax()
ax.contourf(df.direction, df.speed, bins=np.arange(0, 8, 1), cmap=cm.hot)
ax.set_legend()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-52f6cc0ab5a4> in <module>()
#       2
#       3 ax = WindroseAxes.from_ax()
# ----> 4 ax.contourf(df.direction, df.speed, bins=np.arange(0, 8, 1), cmap=cm.hot)
#       5 ax.set_legend()
#       6
#
# NameError: name 'df' is not defined
