# %% [markdown]
# # THIS IS AN EXAMPLE FROM URL :https://mubaris.com/2017/11/05/dataviz-mastery-part1/

# %%
# Data Manipulation
import pandas as pd
# Treemap Ploting
import squarify
# Matplotlib and Seaborn imports
import matplotlib
from matplotlib import style
import matplotlib.pyplot as plt
import seaborn as sns
# Activate Seaborn
sns.set()
# %matplotlib inline
# Large Plot
matplotlib.rcParams['figure.figsize'] = (16.0, 9.0)
# Use ggplot style
style.use('ggplot')

# %%
pwd
# Out:
# 'C:\\Users\\usuario\\PFM_SAB\\master-data-science\\TFM_SaB'

# %%
# Reading CSV file
df = pd.read_csv(".\CONSTABEX\Data\preprocessed_const_csv")

# %%
list(df)
# Out:
# ['Unnamed: 0',
#  'Unnamed: 0.1',
#  'built_area',
#  'modul_price',
#  'weeks_delay',
#  'weeks_duration',
#  'typology']

# %%
# Sort by Revenue
df = df.sort_values(by='weeks_delay', ascending=False)
# Find Percentage
df["Percentage"] = round(1 + 100 * df['weeks_delay'] / sum(df['weeks_delay']), 2)
# Create Treemap Labels
df['typology'] = df['typology'] + " (" + df["Percentage"].astype("str") + "%)"
df.head()
# Out:
#     Unnamed: 0  Unnamed: 0.1  built_area  modul_price  weeks_delay  \
# 51          51            51      106.35       904.23           85
# 67          67            67     2223.27      1034.53           76
# 57          57            57     1827.38       957.66           58
# 68          68            68     6697.16      1193.03           55
# 65          65            65     2329.05       455.40           55
#
#     weeks_duration                                    typology  Percentage
# 51              89    DETACHED (1.66%) (1.66%) (1.66%) (2.66%)        2.66
# 67              26  COLLECTIVE (1.48%) (1.48%) (1.48%) (2.48%)        2.48
# 57              54  COLLECTIVE (1.13%) (1.13%) (1.13%) (2.13%)        2.13
# 68              55  COLLECTIVE (1.07%) (1.07%) (1.07%) (2.07%)        2.07
# 65              80  COLLECTIVE (1.07%) (1.07%) (1.07%) (2.07%)        2.07

# %% [markdown]
# ### EXAMPLE FROM WEB

# %%
# Get Axis and Figure
fig, ax = plt.subplots()
# Our Colormap
cmap = matplotlib.cm.coolwarm
# Min and Max Values
mini = min(df["Percentage"])
maxi = max(df["Percentage"])
# Finding Colors for each tile
norm = matplotlib.colors.Normalize(vmin=mini, vmax=maxi)
colors = [cmap(norm(value)) for value in df["Percentage"]]
# Plotting
squarify.plot(sizes=df["Percentage"], label=df['typology'], alpha=0.8, color=colors)
# Removing Axis
plt.axis('off')
# Invert Y-Axis
plt.gca().invert_yaxis()
# Title
plt.title("Revenue from Star Wars Franchise Movies", fontsize=32)
# Title Positioning
ttl = ax.title
ttl.set_position([.5, 1.05])
# BG Color
fig.set_facecolor('#eeffee')

# %%
# Reading CSV file
df = pd.read_csv(".\CONSTABEX\Data\preprocessed_const_csv")

# %%
def percentager(line):

# %%
df[df['typology']=='DETACHED']
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-41-3008da7dac14> in <module>()
# ----> 1 df[df['typology']=='DETACHED'].df["Percentage"] =1
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    3079             if name in self._info_axis:
#    3080                 return self[name]
# -> 3081             return object.__getattribute__(self, name)
#    3082
#    3083     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'df'

# %%
# Sort by Revenue
df = df.sort_values(by='weeks_delay', ascending=False)
# Find Percentage
df["Percentage"] = round(1 + 100 * df['weeks_delay'] / sum(df['weeks_delay']), 2)
# Create Treemap Labels
df['typology'] = df['typology'] + " (" + df["Percentage"].astype("str") + "%)"
df.head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-19-9f252e1e94a3> in <module>()
#       2 df = df.sort_values(by='weeks_delay', ascending=False)
#       3 # Find Percentage
# ----> 4 df["Percentage"] = [round(1 + 100 * df['weeks_delay'] / sum(df['weeks_delay']), 2)]
#       5 # Create Treemap Labels
#       6 df['typology'] = df['typology'] + " (" + df["Percentage"].astype("str") + "%)"
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __setitem__(self, key, value)
#    2329         else:
#    2330             # set column
# -> 2331             self._set_item(key, value)
#    2332
#    2333     def _setitem_slice(self, key, value):
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in _set_item(self, key, value)
#    2395
#    2396         self._ensure_valid_index(value)
# -> 2397         value = self._sanitize_column(key, value)
# ...

# %%
# Get Axis and Figure
fig, ax = plt.subplots()
# Our Colormap
cmap = matplotlib.cm.coolwarm
# Min and Max Values
mini1 = min(df["Percentage"])
maxi1 = max(df["Percentage"])
mini2 = min(df["Percentage"])
maxi2 = max(df["Percentage"])
mini3 = min(df["Percentage"])
maxi3 = max(df["Percentage"])
mini4 = min(df["Percentage"])
maxi4 = max(df["Percentage"])
# Finding Colors for each tile
norm1 = matplotlib.colors.Normalize(vmin=mini1, vmax=maxi1)
norm2= matplotlib.colors.Normalize(vmin=mini2, vmax=maxi2)
norm3= matplotlib.colors.Normalize(vmin=mini3, vmax=maxi3)
norm4= matplotlib.colors.Normalize(vmin=mini4, vmax=maxi4)

colors1 = [cmap(norm1(value)) for value in df["Percentage"]]
colors2 = [cmap(norm2(value)) for value in df["Percentage"]]
colors3 = [cmap(norm3(value)) for value in df["Percentage"]]
colors4 = [cmap(norm4(value)) for value in df["Percentage"]]

# Plotting
squarify.plot(sizes=df["Percentage"], label=df['typology'], alpha=0.8, color=colors)
# Removing Axis
plt.axis('off')
# Invert Y-Axis
plt.gca().invert_yaxis()
# Title
plt.title("Revenue from Star Wars Franchise Movies", fontsize=32)
# Title Positioning
ttl = ax.title
ttl.set_position([.5, 1.05])
# BG Color
fig.set_facecolor('#eeffee')
